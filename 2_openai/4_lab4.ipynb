# %% [markdown]
# ## Deep Research
#
# One of the classic cross-business Agentic use cases! This is huge.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">A Deep Research agent is broadly applicable to any business area, and to your own day-to-day activities. You can make use of this yourself!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from agents import Agent, trace, Runner, gen_trace_id, function_tool, OpenAIChatCompletionsModel
from agents.model_settings import ModelSettings
from openai import AsyncOpenAI
from pydantic import BaseModel, Field
from dotenv import load_dotenv
from ddgs import DDGS
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
# Out:
# True

# %%
GROQ_BASE_URL = "https://api.groq.com/openai/v1"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

# %%
groq_client = AsyncOpenAI(base_url=GROQ_BASE_URL,
                          api_key=os.getenv("GROQ_API_KEY"))

groq_model = OpenAIChatCompletionsModel(model="qwen/qwen3-32b", openai_client=groq_client)

# gpt-oss-20b is the only Groq model that supports both tool calling and
# json_schema structured outputs simultaneously (required by the Agents SDK).
groq_tool_model = OpenAIChatCompletionsModel(model="openai/gpt-oss-20b", openai_client=groq_client)

groq_writer_model = OpenAIChatCompletionsModel(model="openai/gpt-oss-120b", openai_client=groq_client)

openrouter_client = AsyncOpenAI(base_url="https://openrouter.ai/api/v1", api_key=os.getenv("OPENROUTER_API_KEY"))
openrouter_model = OpenAIChatCompletionsModel(openai_client=openrouter_client, model="qwen/qwen3-32b")

# gpt-4o-mini via OpenRouter: supports streaming + json_schema together (needed for writer_agent)
openrouter_writer_model = OpenAIChatCompletionsModel(openai_client=openrouter_client, model="openai/gpt-4o-mini")

# %% [markdown]
# ## OpenAI Hosted Tools
#
# OpenAI Agents SDK includes the following hosted tools:
#
# The `WebSearchTool` lets an agent search the web.
# The `FileSearchTool` allows retrieving information from your OpenAI Vector Stores.
# The `ComputerTool` allows automating computer use tasks like taking screenshots and clicking.
#
# ### Important note - API charge of WebSearchTool
#
# This is costing me 2.5 cents per call for OpenAI WebSearchTool. That can add up to $2-$3 for the next 2 labs. We'll use free and low cost Search tools with other platforms, so feel free to skip running this if the cost is a concern. Also student Christian W. pointed out that OpenAI can sometimes charge for multiple searches for a single call, so it could sometimes cost more than 2.5 cents per call.
#
# Costs are here: https://platform.openai.com/docs/pricing#web-search

# %%
@function_tool
def web_search(query: str) -> str:
    """Search the web for the given query and return summarized results."""
    with DDGS() as ddgs:
        results = list(ddgs.text(query, max_results=5))
    return "\n\n".join(
        f"Title: {r['title']}\nURL: {r['href']}\nSnippet: {r['body']}"
        for r in results
    )

INSTRUCTIONS = "You are a research assistant. Given a search term, you search the web for that term and \
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 \
words. Capture the main points. Write succintly, no need to have complete sentences or good \
grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the \
essence and ignore any fluff. Do not include any additional commentary other than the summary itself."

search_agent = Agent(
    name="Search agent",
    instructions=INSTRUCTIONS,
    tools=[web_search],
    model=groq_model,
    model_settings=ModelSettings(tool_choice="required"),
)

# %%
message = "Latest AI Agent frameworks in 2025"

with trace("Search"):
    result = await Runner.run(search_agent, message)

display(Markdown(result.final_output))
# Out:
# AI agent frameworks in 2025 prioritize orchestration, security, and production readiness for enterprise use. Key frameworks include Agentbase, AutoGen, LangChain, CrewAI, Google ADK, and OpenAI SDK, highlighted for scalability and cross-cloud compatibility. Tools like Solo.io emphasize secure agent-to-agent communication and compliance controls, while IBM/Coursera’s training focuses on agentic AI design principles for developers.
#
# A 2025 guide (AgentBase) details 25+ frameworks, stressing adaptability in dynamic environments. Solo.io’s infrastructure bridges cloud-native systems with agent-based workflows, enabling policy-driven security. Trends highlight AI’s productivity impact, consumer adoption growth (10K+ US merchants using AI tools), and data-driven insights from 93M consumer datasets.
#
# Top frameworks are evaluated for features like memory management, multi-agent collaboration, and integration with LLMs. AutoGen and LangChain excel in automation pipelines, while Google ADK supports enterprise-grade deployment. Emerging tools address ethical risks, bias mitigation, and real-time decision-making. ConsumerEdge notes a spending boom in AI adoption, with 70% of firms prioritizing agentic AI for operational efficiency.

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ### We will now use Structured Outputs, and include a description of the fields

# %%
# See note above about cost of WebSearchTool

HOW_MANY_SEARCHES = 3

INSTRUCTIONS = f"You are a helpful research assistant. Given a query, come up with a set of web searches \
to perform to best answer the query. Output {HOW_MANY_SEARCHES} terms to query for."

# Use Pydantic to define the Schema of our response - this is known as "Structured Outputs"
# With massive thanks to student Wes C. for discovering and fixing a nasty bug with this!

class WebSearchItem(BaseModel):
    reason: str = Field(description="Your reasoning for why this search is important to the query.")

    query: str = Field(description="The search term to use for the web search.")


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem] = Field(description="A list of web searches to perform to best answer the query.")


planner_agent = Agent(
    name="PlannerAgent",
    instructions=INSTRUCTIONS,
    model=openrouter_model,
    output_type=WebSearchPlan,
)

# %%
message = "Latest AI Agent frameworks in 2025"

with trace("Search"):
    result = await Runner.run(planner_agent, message)
    print(result.final_output)
# Out:
# searches=[WebSearchItem(reason="To determine the latest AI agent frameworks as of 2025, it's important to look for recent publications, articles, and releases from 2024 and 2025.", query='latest AI agent frameworks 2024 2025'), WebSearchItem(reason='AI conferences such as NeurIPS, ICML, or ICLR often publish new frameworks; checking their 2024 and 2025 proceedings could reveal the latest developments.', query='2024 2025 AI conferences agent frameworks'), WebSearchItem(reason='Leading tech companies often release new AI frameworks; checking the official announcements and blogs from companies like Google, Meta, and Anthropic around 2024-2025 can help identify new agent frameworks.', query='2024 2025 AI agent frameworks company releases')]

# %%
@function_tool
def send_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("felipe.sanchez2028@gmail.com") # Change this to your verified email
    to_email = To("santihs.sanchez@gmail.com") # Change this to your email
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return "success"

# %%
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given subject and HTML body', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x7f84f5b06020>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %%
INSTRUCTIONS = """You are able to send a nicely formatted HTML email based on a detailed report.
You will be provided with a detailed report. You should use your tool to send one email, providing the 
report converted into clean, well presented HTML with an appropriate subject line."""

email_agent = Agent(
    name="Email agent",
    instructions=INSTRUCTIONS,
    tools=[send_email],
    model=openrouter_model,
)

# %%
INSTRUCTIONS = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words."
)


class ReportData(BaseModel):
    short_summary: str = Field(description="A short 2-3 sentence summary of the findings.")

    markdown_report: str = Field(description="The final report")

    follow_up_questions: list[str] = Field(description="Suggested topics to research further")


writer_agent = Agent(
    name="WriterAgent",
    instructions=INSTRUCTIONS,
    model=openrouter_writer_model,
    output_type=ReportData,
)

# %% [markdown]
# ### The next 3 functions will plan and execute the search, using planner_agent and search_agent

# %%
async def plan_searches(query: str):
    """ Use the planner_agent to plan which searches to run for the query """
    print("Planning searches...")
    result = await Runner.run(planner_agent, f"Query: {query}")
    print(f"Will perform {len(result.final_output.searches)} searches")
    return result.final_output

async def perform_searches(search_plan: WebSearchPlan):
    """ Call search() for each item in the search plan """
    print("Searching...")
    tasks = [asyncio.create_task(search(item)) for item in search_plan.searches]
    results = await asyncio.gather(*tasks)
    print("Finished searching")
    return results

async def search(item: WebSearchItem):
    """ Use the search agent to run a web search for each item in the search plan """
    input = f"Search term: {item.query}\nReason for searching: {item.reason}"
    result = await Runner.run(search_agent, input)
    return result.final_output

# %% [markdown]
# ### The next 2 functions write a report and email it

# %%
async def write_report(query: str, search_results: list[str]):
    """ Use the writer agent to write a report based on the search results"""
    print("Thinking about report...")
    input = f"Original query: {query}\nSummarized search results: {search_results}"
    result = await Runner.run(writer_agent, input)
    print("Finished writing report")
    return result.final_output

async def send_email(report: ReportData):
    """ Use the email agent to send an email with the report """
    print("Writing email...")
    result = await Runner.run(email_agent, report.markdown_report)
    print("Email sent")
    return report

# %% [markdown]
# ### Showtime!

# %%
query ="Latest AI Agent frameworks in 2025"

with trace("Research trace"):
    print("Starting research...")
    search_plan = await plan_searches(query)
    print(search_plan)
    search_results = await perform_searches(search_plan)
    print(search_results)
    report = await write_report(query, search_results)
    print(report)
    await send_email(report)  
    print("Hooray!")
# Out:
# Starting research...
# Planning searches...
# Will perform 3 searches
# searches=[WebSearchItem(reason='Identifies the latest AI agent frameworks that have been developed or updated in 2025.', query='latest AI agent frameworks 2025'), WebSearchItem(reason='Provides information on upcoming or newly announced AI agent frameworks for 2025.', query='new AI agent frameworks 2025 announcements'), WebSearchItem(reason='Highlights top AI agent frameworks as of 2025, which may include rankings or comparisons.', query='top AI agent frameworks 2025')]
# Searching...
# Finished searching
# ['Top AI agent frameworks in 2025 include AutoGen, LangChain, CrewAI, LangGraph, and Agentbase, with additional mentions of Google ADK, OpenAI SDK, and AgentKit. These frameworks prioritize modular agent composition, multi-agent collaboration, and seamless integration with large language models (LLMs). Frameworks like LangChain and AutoGen emphasize workflow automation and tool orchestration, while Agentbase focuses on production-ready agent deployment for enterprise use cases. Emerging tools such as LangGraph introduce visual interface designs for configuring agent logic, and CrewAI enhances team-based agent interactions via role assignments and task delegation.\n\nKey trends highlight increased adoption in autonomous systems, real-time decision-making pipelines, and cross-domain automation. Enterprise applications span customer service bots, supply chain optimization, and code generation agents. Features differentiating top frameworks include support for multi-modal inputs (text, image, audio), LLM-agnostic architecture, and built-in reinforcement learning for adaptive agents. Developers prioritize frameworks with robust API documentation, active community support, and pre-built templates for rapid prototyping. Open-source frameworks like AutoGen and CrewAI maintain strong traction due to customizable agent pipelines, whereas proprietary solutions like Google ADK emphasize enterprise security and compliance.', 'Microsoft announced the Agent Framework during Build 2025, a public preview SDK enabling multi-agent AI development via OpenAPI and integration with Azure AI Foundry. Also highlighted was "Open Agentic Web," an interoperable framework allowing autonomous agent collaboration with humans. The Agent Framework includes tools for scalability, modularity, and real-time agent coordination, targeting enterprise AI applications.  \n\nOther 2025 announcements include updates to open-source agent frameworks like AutoFlow and LangChain++, emphasizing modular architecture, customizable workflows, and support for hybrid models (on-prem/cloud). New frameworks such as Agenix (for LLM-powered agents) and Metaflow (for data-driven autonomous agents) focus on low-code/no-code interfaces and domain-specific use cases (e.g., healthcare, finance).  \n\nAnalysis of 2025 trends shows frameworks prioritize extensibility, ethical AI guardrails, and cross-platform compatibility. Guides recommend evaluating frameworks based on deployment needs, model support, and integration with existing tools. Open-source options remain popular for experimentation, while enterprise frameworks emphasize security and compliance. Key innovations include agent orchestration, human-in-the-loop workflows, and federated learning support.', 'Top AI agent frameworks in 2025 include **LangChain**, **LangGraph**, **CrewAI**, **Microsoft AutoGen**, and **OpenAI Swarm**, with rankings and comparisons across enterprise use cases. LangChain leads as the top framework for multi-agent orchestration, followed by CrewAI for role-playing scenarios and AutoGen for task automation. Microsoft AutoGen and LangGraph are highlighted for versatility, while OpenAI Swarm gains traction for collaborative agent workflows. Enterprise-focused tools like **HuggingGPT**, **DeepSeek**, and **PromptFlow** are also noted for production-grade deployments.\n\nDeveloper resources emphasize frameworks prioritizing scalability and integration, with **LangGraph** excelling in visual orchestration and **DSPy** (MIT) enabling dynamic reasoning. Microsoft’s **Semantic Kernel** and **Phidata** (for finance/biolab workflows) address niche verticals. Tools like **PromptFlow** streamline prompt engineering, and **Agno** offers lightweight agent deployment. The landscape reflects trends toward modular design, hybrid LLM-synthesis architectures, and domain-specific specialization across research institutions and tech giants.']
# Thinking about report...
# Finished writing report
# short_summary='In 2025, key AI agent frameworks include LangChain, AutoGen, and CrewAI, emphasizing modularity, collaboration, and integration with large language models. Trends reflect an increased focus on security, extensibility, and ethical AI, with applications spanning from customer service to healthcare and finance.' markdown_report='# Latest AI Agent Frameworks in 2025\n\n## Introduction  \nAs we enter the landscape of 2025, artificial intelligence continues to integrate deeply into various sectors, driven by advancements in AI agent frameworks. This report explores the latest frameworks that have emerged, key trends, and future implications for AI agents. Our findings indicate a strong emphasis on modular architecture, multi-agent collaboration, and seamless integration with large language models (LLMs).\n\n## Overview of Top AI Agent Frameworks in 2025\nThe AI agent frameworks that have gained prominence this year include:\n1. **LangChain**  \n2. **AutoGen**  \n3. **CrewAI**  \n4. **LangGraph**  \n5. **Agentbase**  \n6. **Google ADK**  \n7. **OpenAI SDK**  \n8. **AgentKit**\n\nThese frameworks either excel in specific functionalities or provide comprehensive solutions for a wide range of use cases.\n\n### LangChain  \nLangChain is recognized as a leader in multi-agent orchestration, making it suitable for applications requiring complex decision-making processes. It prioritizes automation in workflows and boasts custom integration capabilities with LLMs.\n\n### AutoGen  \nAnother strong contender, AutoGen focuses on streamlining task automation, offering significant flexibility for developers aiming for production-ready deployments.\n\n### CrewAI  \nCrewAI is tailored to enhance team-based interactions among agents, allowing for role assignments and strategic task allocations, thereby fostering efficient project collaboration.\n\n### LangGraph  \nLangGraph stands out with its visual design interface for agent configuration, which assists developers in orchestrating agent logic visually rather than through standard coding methods. \n\n### Agentbase  \nThis framework is particularly designed for enterprise-level applications, enabling scalable and secure agent deployment in production environments.\n\n### Emerging Frameworks  \nNew entrants like Agenix and Metaflow are also making waves in 2025. Agenix focuses on LLM-powered agents, while Metaflow caters to domain-specific scenarios, making them essential tools in specialized industries such as healthcare and finance.\n\n## Key Features and Innovations\n### Modular Architecture  \nThe common thread across these frameworks is a modular design. This modularity fosters extensibility, enabling seamless enhancements, and customization for developers. Additionally, workflows can be tailored according to specific organizational needs.\n\n### Multi-Agent Collaboration  \nFrameworks like CrewAI and Microsoft’s Agent Framework support collaborative work between multiple agents, optimizing task completion through dynamic role assignments and real-time communications.\n\n### Integration with LLMs  \nA major characteristic of the leading frameworks is their integration capacity with LLMs. This integration empowers agents to leverage natural language processing capabilities for sophisticated decision-making, conversational interfaces, and content generation.\n\n## Notable Trends in AI Agent Frameworks\nThe current trends reflect how rapidly AI technology is evolving. Key observations include:\n### Increased Adoption in Autonomous Systems  \nAI agents have made significant inroads into autonomous systems, driving real-time decision-making capabilities that are crucial in dynamic environments.\n\n### Cross-Domain Automation  \nFrameworks are increasingly being adopted across various sectors, enabling automation in customer service, supply chains, and even in application areas like code generation.\n\n### Ethical AI and Security  \nWith the rising concerns over privacy and ethical impli ...
# Writing email...
# Email sent
# Hooray!

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thanks.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00cc00;">Congratulations on your progress, and a request</h2>
#             <span style="color:#00cc00;">You've reached an important moment with the course; you've created a valuable Agent using one of the latest Agent frameworks. You've upskilled, and unlocked new commercial possibilities. Take a moment to celebrate your success!<br/><br/>Something I should ask you -- my editor would smack me if I didn't mention this. If you're able to rate the course on Udemy, I'd be seriously grateful: it's the most important way that Udemy decides whether to show the course to others and it makes a massive difference.<br/><br/>And another reminder to <a href="https://www.linkedin.com/in/eddonner/">connect with me on LinkedIn</a> if you wish! If you wanted to post about your progress on the course, please tag me and I'll weigh in to increase your exposure.
#             </span>
#         </td>
#     </tr>
