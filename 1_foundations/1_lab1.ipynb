# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins AIzaSyBf

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

# from openai import OpenAI
from google import genai
from google.genai import types

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

# openai = OpenAI()
openai = genai.Client()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

# response = openai.chat.completions.create(
#     model="gpt-4.1-nano",
#     messages=messages
# )

# print(response.choices[0].message.content)

response = openai.models.generate_content(
    model="gemini-2.5-flash",
    # parse messages valid for google
    contents=messages[0]['content']
)

print(response.text)
# Out:
# 2+2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

# response = openai.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=messages
# )

# question = response.choices[0].message.content

# print(question)

response = openai.models.generate_content(
    model="gemini-2.5-flash",
    # parse messages valid for google
    contents=messages[0]['content']
)

question = response.text
print(question)
# Out:
# You have a list of five distinct positive integers, W, X, Y, Z, Q. You know the following:
#
# 1.  W is a perfect square.
# 2.  X is a prime number.
# 3.  Y is a multiple of 7.
# 4.  Z is a multiple of 3, but not a multiple of 9.
# 5.  Q is a power of 2.
# 6.  When the integers are arranged in ascending order, the sum of the first three is 30, and the sum of the last three is 45.
# 7.  The largest integer is less than 20.
#
# What is the value of Y?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

# response = openai.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=messages
# )

# answer = response.choices[0].message.content

response = openai.models.generate_content(
    model="gemini-2.5-flash",
    # parse messages valid for google
    contents=messages[0]['content']
)
answer = response.text
print(answer)
# Out:
# Let the five distinct positive integers be W, X, Y, Z, Q.
# Let their properties be:
# 1.  W is a perfect square. Possible values (<20): {1, 4, 9, 16}
# 2.  X is a prime number. Possible values (<20): {2, 3, 5, 7, 11, 13, 17, 19}
# 3.  Y is a multiple of 7. Possible values (<20): {7, 14}
# 4.  Z is a multiple of 3, but not a multiple of 9. Possible values (<20): {3, 6, 12, 15} (Multiples of 3 are 3, 6, 9, 12, 15, 18. Multiples of 9 are 9, 18. Removing multiples of 9 leaves 3, 6, 12, 15.)
# 5.  Q is a power of 2. Possible values (<20): {1, 2, 4, 8, 16}
#
# Let the integers arranged in ascending order be a, b, c, d, e. Since they are distinct positive integers, a < b < c < d < e.
#
# From condition 7: The largest integer is less than 20. So e < 20, meaning e can be at most 19.
# From condition 6:
# a + b + c = 30  (1)
# c + d + e = 45  (2)
#
# We can deduce bounds for c:
# Since a < b < c, then a + b + c < 3c. So 30 < 3c => c > 10.
# Since c < d < e, then c + d + e > 3c. So 45 > 3c => c < 15.
# So, c must be an integer from {11, 12, 13, 14}.
#
# Let's list all possible sets {a,b,c,d,e} based on these conditions.
# -   If c = 11: a+b=19. Possible (a,b) pairs (a<b<11): (8,9).
#     d+e=34. Possible (d,e) pairs (11<d<e<20): (15,19), (16,18).
#     Candidate sets: (8,9,11,15,19), (8,9,11,16,18).
# -   If c = 12: a+b=18. Possible (a,b) pairs (a<b<12): (7,11), (8,10).
#     d+e=33. Possible (d,e) pairs (12<d<e<20): (14,19), (15,18), (16,17).
#     Candidate sets: (7,11,12,14,19), (7,11,12,15,18), (7,11,12,16,17), (8,10,12,14,19), (8,10,12,15,18), (8,10,12,16,17).
# -   If c = 13: a+b=17. Possible (a,b) pairs (a<b<13): (5,12), (6,11), (7,10), (8,9).
#     d+e=32. Possible (d,e) pairs (13<d<e<20): (14,18), (15,17). (14,19, sum 33; 13+19; 14+18; 15+17)
#     Candidate sets: (5,12,13,14,18), (5,12,13,15,17), (6,11,13,14,18), (6,11,13,15,17), (7,10,13,14,18), (7,10,13,15,17), (8,9,13,14,18), (8,9,13,15,17).
#     (Checking 14,19 for d+e=32: d=14,e=18 or d=15,e=17)
# -   If c = 14: a+b=16. Possible (a,b) pairs (a<b<14): (3,13), (4,12), (5,11), (6,10), (7,9).
#     d+e=31. Possible (d,e) pairs (14<d<e<20): (15,16).
#     Candidate sets: (3,13,14,15,16), (4,12,14,15,16), (5,11,14,15,16), (6,10,14,15,16), (7,9,14,15,16).
#
# Now, we need to assign W, X, Y, Z, Q to the numbers in each set, ensuring they are distinct and satisfy their properties.
# Let's list the characteristics of numbers less than 20:
# -   **Pure Properties** (number can only fulfill one role, or no role):
#     -   5, 11, 13, 17, 19 are only X (prime).
#     -   6, 12, 15 are only Z (multiple of 3, not 9).
#     -   8 is only Q (power of 2).
#     -   9 is only W (perfect square).
#     -   14 is only Y (multiple of 7). (It's not prime, not square, not power of 2, not mult of 3 not 9)
#     -   10, 18 have no properties from W,X,Y,Z,Q and thus cannot be in the final set.
# -   **Overlapping Properties**:
#     -   1: W or Q
#     -   2: X or Q
#     -   3: X or Z
#     -   4: W or Q
#     -   7: X or Y
#     -   16: W or Q
#
# Crucially, W, X, Y, Z, Q must be five *distinct* integers. This means if a number (e.g., 16) has multiple properties (W and Q), it can only be assigned to *one* of W or Q. The other property must be satisfied by a different number in the set.
#
# First, filter out candidate sets containing 10 or 18 (which have no designated property):
# -   (8,9,11,16,18) - Invalid (contains 18)
# -   (7,11,12,15,18) - Invalid (contains 18)
# -   (8,10,12,14,19) - Invalid (contains 10)
# -   (8,10,12,15,18) - Invalid (contains 10, 18)
# -   (8,10,12,16,17) - Invalid (contains 10)
# -   (5,12,13,14,18) - Invalid (contains 18)
# -   (6,11,13,14,18) - Invalid (contains 18)
# -   (7,10,13,14,18) - Invalid (contains 10, 18)
# -   (7,10,13,15,17) - Invalid (contains 10)
# -   (8,9,13,14,18) - Invalid (contains 18)
# -   (6,10,14,15,16) - Invalid (contains 10)
#
# Remaining candidate sets:
# 1.  (8,9,11,15,19)
# 2.  (7,11,12,14,19)
# 3.  (7,11,12,16,17)
# 4.  (5,12,13,15,17)
# 5.  (6,11,13,15,17)
# 6.  (8,9,13,15,17)
# 7.  (3,13,14,15,16)
# 8.  (4,12,14,15,16)
# 9.  (5,11,14,15,16)
# 10. (7,9,14,15,16)
#
# Let's analyze these sets.
# -   **Sets containing 14**: (2, 7, 8, 9, 10).
#     As established, 14 can only be Y. So for these sets, Y=14.
#     -   Set 2: (7,11,12,14,19). Y=14. Remaining: {7,11,12,19} for W,X,Z,Q.
#         -   Z must be 12.
#         -   X must be from {7,11,19}.
#         -   No number for W (perfect square) or Q (power of 2). Invalid.
#     -   Set 7: (3,13,14,15,16). Y=14. Remaining: {3,13,15,16} for W,X,Z,Q.
#         -   Z must be 3 or 15.
#         -   X must be 3 or 13.
#         -   16 is the only perfect square (W) and only power of 2 (Q). But W and Q must be distinct. So 16 cannot be both W and Q. Invalid.
#     -   Set 8: (4,12,14,15,16). Y=14. Remaining: {4,12,15,16} for W,X,Z,Q.
#         -   Z must be 12 or 15.
#         -   W must be 4 or 16.
#         -   Q must be 4 or 16.
#         -   No prime number for X. Invalid.
#     -   Set 9: (5,11,14,15,16). Y=14. Remaining: {5,11,15,16} for W,X,Z,Q.
#         -   Z must be 15.
#         -   X must be 5 or 11.
#         -   16 is the only perfect square (W) and only power of 2 (Q). W and Q must be distinct. Invalid.
#     -   Set 10: (7,9,14,15,16). Y=14. Remaining: {7,9,15,16} for W,X,Z,Q.
#         -   7 is prime, so X=7.
#         -   9 is a perfect square, so W=9.
#         -   15 is a multiple of 3, not 9, so Z=15.
#         -   16 is a power of 2, so Q=16.
#         -   All properties are uniquely assigned to distinct numbers: W=9, X=7, Y=14, Z=15, Q=16.
#         -   Let's check this set: {7,9,14,15,16}.
#             -   W=9 (perfect square) - Yes
#             -   X=7 (prime number) - Yes
#             -   Y=14 (multiple of 7) - Yes
#             -   Z=15 (multiple of 3, not 9) - Yes
#             -   Q=16 (power of 2) - Yes
#             -   The five integers are {7,9,14,15,16}.
#             -   Arranged in ascending order: a=7, b=9, c=14, d=15, e=16.
#             -   a+b+c = 7+9+14 = 30. (Correct)
#             -   c+d+e = 14+15+16 = 45. (Correct)
#             -   e=16 < 20. (Correct)
#         This set satisfies all conditions. Therefore, Y=14.
#
# We can stop here, as we have found a unique solution. However, for completeness, let's briefly check the remaining sets (which do not contain 14). This means Y must be 7 for these sets.
#
# -   **Sets containing 7 (so Y=7) and not 14**: (1, 3, 4, 5, 6).
#     -   Set 1: (8,9,11,15,19). No 7 or 14. Invalid.
#     -   Set 3: (7,11,12,16,17). Y=7. Remaining: {11,12,16,17} for W,X,Z,Q.
#         -   Z=12.
#         -   X must be 11 or 17.
#         -   W must be 16. Q must be 16. W and Q must be distinct. Invalid.
#     -   Set 4: (5,12,13,15,17). No 7 or 14. Invalid.
#     -   Set 5: (6,11,13,15,17). No 7 or 14. Invalid.
#     -   Set 6: (8,9,13,15,17). No 7 or 14. Invalid.
#
# Thus, the set (7,9,14,15,16) is the only valid solution, and the value of Y is 14.
#
# The final answer is $\boxed{14}$.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let the five distinct positive integers be W, X, Y, Z, Q.
# Let their properties be:
# 1.  W is a perfect square. Possible values (<20): {1, 4, 9, 16}
# 2.  X is a prime number. Possible values (<20): {2, 3, 5, 7, 11, 13, 17, 19}
# 3.  Y is a multiple of 7. Possible values (<20): {7, 14}
# 4.  Z is a multiple of 3, but not a multiple of 9. Possible values (<20): {3, 6, 12, 15} (Multiples of 3 are 3, 6, 9, 12, 15, 18. Multiples of 9 are 9, 18. Removing multiples of 9 leaves 3, 6, 12, 15.)
# 5.  Q is a power of 2. Possible values (<20): {1, 2, 4, 8, 16}
#
# Let the integers arranged in ascending order be a, b, c, d, e. Since they are distinct positive integers, a < b < c < d < e.
#
# From condition 7: The largest integer is less than 20. So e < 20, meaning e can be at most 19.
# From condition 6:
# a + b + c = 30  (1)
# c + d + e = 45  (2)
#
# We can deduce bounds for c:
# Since a < b < c, then a + b + c < 3c. So 30 < 3c => c > 10.
# Since c < d < e, then c + d + e > 3c. So 45 > 3c => c < 15.
# So, c must be an integer from {11, 12, 13, 14}.
#
# Let's list all possible sets {a,b,c,d,e} based on these conditions.
# -   If c = 11: a+b=19. Possible (a,b) pairs (a<b<11): (8,9).
#     d+e=34. Possible (d,e) pairs (11<d<e<20): (15,19), (16,18).
#     Candidate sets: (8,9,11,15,19), (8,9,11,16,18).
# -   If c = 12: a+b=18. Possible (a,b) pairs (a<b<12): (7,11), (8,10).
#     d+e=33. Possible (d,e) pairs (12<d<e<20): (14,19), (15,18), (16,17).
#     Candidate sets: (7,11,12,14,19), (7,11,12,15,18), (7,11,12,16,17), (8,10,12,14,19), (8,10,12,15,18), (8,10,12,16,17).
# -   If c = 13: a+b=17. Possible (a,b) pairs (a<b<13): (5,12), (6,11), (7,10), (8,9).
#     d+e=32. Possible (d,e) pairs (13<d<e<20): (14,18), (15,17). (14,19, sum 33; 13+19; 14+18; 15+17)
#     Candidate sets: (5,12,13,14,18), (5,12,13,15,17), (6,11,13,14,18), (6,11,13,15,17), (7,10,13,14,18), (7,10,13,15,17), (8,9,13,14,18), (8,9,13,15,17).
#     (Checking 14,19 for d+e=32: d=14,e=18 or d=15,e=17)
# -   If c = 14: a+b=16. Possible (a,b) pairs (a<b<14): (3,13), (4,12), (5,11), (6,10), (7,9).
#     d+e=31. Possible (d,e) pairs (14<d<e<20): (15,16).
#     Candidate sets: (3,13,14,15,16), (4,12,14,15,16), (5,11,14,15,16), (6,10,14,15,16), (7,9,14,15,16).
#
# Now, we need to assign W, X, Y, Z, Q to the numbers in each set, ensuring they are distinct and satisfy their properties.
# Let's list the characteristics of numbers less than 20:
# -   **Pure Properties** (number can only fulfill one role, or no role):
#     -   5, 11, 13, 17, 19 are only X (prime).
#     -   6, 12, 15 are only Z (multiple of 3, not 9).
#     -   8 is only Q (power of 2).
#     -   9 is only W (perfect square).
#     -   14 is only Y (multiple of 7). (It's not prime, not square, not power of 2, not mult of 3 not 9)
#     -   10, 18 have no properties from W,X,Y,Z,Q and thus cannot be in the final set.
# -   **Overlapping Properties**:
#     -   1: W or Q
#     -   2: X or Q
#     -   3: X or Z
#     -   4: W or Q
#     -   7: X or Y
#     -   16: W or Q
#
# Crucially, W, X, Y, Z, Q must be five *distinct* integers. This means if a number (e.g., 16) has multiple properties (W and Q), it can only be assigned to *one* of W or Q. The other property must be satisfied by a different number in the set.
#
# First, filter out candidate sets containing 10 or 18 (which have no designated property):
# -   (8,9,11,16,18) - Invalid (contains 18)
# -   (7,11,12,15,18) - Invalid (contains 18)
# -   (8,10,12,14,19) - Invalid (contains 10)
# -   (8,10,12,15,18) - Invalid (contains 10, 18)
# -   (8,10,12,16,17) - Invalid (contains 10)
# -   (5,12,13,14,18) - Invalid (contains 18)
# -   (6,11,13,14,18) - Invalid (contains 18)
# -   (7,10,13,14,18) - Invalid (contains 10, 18)
# -   (7,10,13,15,17) - Invalid (contains 10)
# -   (8,9,13,14,18) - Invalid (contains 18)
# -   (6,10,14,15,16) - Invalid (contains 10)
#
# Remaining candidate sets:
# 1.  (8,9,11,15,19)
# 2.  (7,11,12,14,19)
# 3.  (7,11,12,16,17)
# 4.  (5,12,13,15,17)
# 5.  (6,11,13,15,17)
# 6.  (8,9,13,15,17)
# 7.  (3,13,14,15,16)
# 8.  (4,12,14,15,16)
# 9.  (5,11,14,15,16)
# 10. (7,9,14,15,16)
#
# Let's analyze these sets.
# -   **Sets containing 14**: (2, 7, 8, 9, 10).
#     As established, 14 can only be Y. So for these sets, Y=14.
#     -   Set 2: (7,11,12,14,19). Y=14. Remaining: {7,11,12,19} for W,X,Z,Q.
#         -   Z must be 12.
#         -   X must be from {7,11,19}.
#         -   No number for W (perfect square) or Q (power of 2). Invalid.
#     -   Set 7: (3,13,14,15,16). Y=14. Remaining: {3,13,15,16} for W,X,Z,Q.
#         -   Z must be 3 or 15.
#         -   X must be 3 or 13.
#         -   16 is the only perfect square (W) and only power of 2 (Q). But W and Q must be distinct. So 16 cannot be both W and Q. Invalid.
#     -   Set 8: (4,12,14,15,16). Y=14. Remaining: {4,12,15,16} for W,X,Z,Q.
#         -   Z must be 12 or 15.
#         -   W must be 4 or 16.
#         -   Q must be 4 or 16.
#         -   No prime number for X. Invalid.
#     -   Set 9: (5,11,14,15,16). Y=14. Remaining: {5,11,15,16} for W,X,Z,Q.
#         -   Z must be 15.
#         -   X must be 5 or 11.
#         -   16 is the only perfect square (W) and only power of 2 (Q). W and Q must be distinct. Invalid.
#     -   Set 10: (7,9,14,15,16). Y=14. Remaining: {7,9,15,16} for W,X,Z,Q.
#         -   7 is prime, so X=7.
#         -   9 is a perfect square, so W=9.
#         -   15 is a multiple of 3, not 9, so Z=15.
#         -   16 is a power of 2, so Q=16.
#         -   All properties are uniquely assigned to distinct numbers: W=9, X=7, Y=14, Z=15, Q=16.
#         -   Let's check this set: {7,9,14,15,16}.
#             -   W=9 (perfect square) - Yes
#             -   X=7 (prime number) - Yes
#             -   Y=14 (multiple of 7) - Yes
#             -   Z=15 (multiple of 3, not 9) - Yes
#             -   Q=16 (power of 2) - Yes
#             -   The five integers are {7,9,14,15,16}.
#             -   Arranged in ascending order: a=7, b=9, c=14, d=15, e=16.
#             -   a+b+c = 7+9+14 = 30. (Correct)
#             -   c+d+e = 14+15+16 = 45. (Correct)
#             -   e=16 < 20. (Correct)
#         This set satisfies all conditions. Therefore, Y=14.
#
# We can stop here, as we have found a unique solution. However, for completeness, let's briefly check the remaining sets (which do not contain 14). This means Y must be 7 for these sets.
#
# -   **Sets containing 7 (so Y=7) and not 14**: (1, 3, 4, 5, 6).
#     -   Set 1: (8,9,11,15,19). No 7 or 14. Invalid.
#     -   Set 3: (7,11,12,16,17). Y=7. Remaining: {11,12,16,17} for W,X,Z,Q.
#         -   Z=12.
#         -   X must be 11 or 17.
#         -   W must be 16. Q must be 16. W and Q must be distinct. Invalid.
#     -   Set 4: (5,12,13,15,17). No 7 or 14. Invalid.
#     -   Set 5: (6,11,13,15,17). No 7 or 14. Invalid.
#     -   Set 6: (8,9,13,15,17). No 7 or 14. Invalid.
#
# Thus, the set (7,9,14,15,16) is the only valid solution, and the value of Y is 14.
#
# The final answer is $\boxed{14}$.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Hello world Java 25"}]

# Then make the first call:

response = openai.models.generate_content(
    model="gemini-2.5-flash",
    # parse messages valid for google
    contents=messages[0]['content']
)

# Then read the business idea:

business_idea = response.text
print(business_idea)

# And repeat! In the next message, include the business idea within the message
messages = [{"role": "user", "content": f"Give me a business idea based on: {business_idea}"}]

response = openai.models.generate_content(
    model="gemini-2.5-flash",
    # parse messages valid for google
    contents=messages[0]['content']
)
business_idea = response.text
display(Markdown(business_idea))
# Out:
# "Hello, World!" in Java 25 can be written in a couple of ways, depending on whether you want to use the traditional syntax or leverage new preview features aimed at reducing boilerplate.
#
# **Important Note:** As of my last update, Java 25 is an upcoming version (expected September 2025). The features discussed for Java 21+ (like Unnamed Classes) are already available in preview modes in recent versions and are expected to be refined and potentially standardized in future versions like 25.
#
# ---
#
# ### 1. The Traditional (and Still Recommended) Way
#
# This is the standard "Hello, World!" program that has been valid for many Java versions and remains fully supported in Java 25.
#
# **`HelloWorld.java`:**
#
# ```java
# public class HelloWorld {
#     public static void main(String[] args) {
#         System.out.println("Hello, World from Java 25!");
#     }
# }
# ```
#
# **How to Compile and Run (assuming you have a Java 25 JDK installed):**
#
# 1.  **Save:** Save the code above in a file named `HelloWorld.java`.
# 2.  **Compile:** Open a terminal or command prompt, navigate to the directory where you saved the file, and run:
#     ```bash
#     javac HelloWorld.java
#     ```
# 3.  **Run:** After successful compilation, run the program:
#     ```bash
#     java HelloWorld
#     ```
#
# **Expected Output:**
#
# ```
# Hello, World from Java 25!
# ```
#
# ---
#
# ### 2. Using Unnamed Classes and Instance Main Methods (Preview Feature)
#
# Java has introduced a preview feature (JEP 463, part of Project Amber, available in Java 21 and later) called "Unnamed Classes and Instance Main Methods". This feature aims to simplify the "Hello, World!" program and similar small applications by removing some of the boilerplate.
#
# With this feature, you don't need to declare a class explicitly, and the `main` method doesn't need to be `public static void main(String[] args)`. You can just declare a `void main()` method directly at the top level of the file.
#
# **`HelloMinimal.java`:**
#
# ```java
# // Requires --enable-preview --source 25 to compile and run
# void main() {
#     System.out.println("Hello, World from Java 25 (minimal)!");
# }
# ```
#
# **How to Compile and Run (with preview features enabled):**
#
# 1.  **Save:** Save the code above in a file named `HelloMinimal.java`.
# 2.  **Compile:** You **must** enable preview features when compiling:
#     ```bash
#     javac --enable-preview --source 25 HelloMinimal.java
#     ```
#     (If you are on an older Java 21/22/23/24, replace `--source 25` with your current Java version, e.g., `--source 21`).
# 3.  **Run:** You **must** also enable preview features when running:
#     ```bash
#     java --enable-preview HelloMinimal
#     ```
#
# **Expected Output:**
#
# ```
# Hello, World from Java 25 (minimal)!
# ```
#
# **Why this feature?**
#
# *   It makes Java more accessible for beginners by reducing the initial complexity of `public static void main(String[] args)`.
# *   It simplifies writing small scripts or utility programs.
# *   It's a step towards potentially supporting "shebang" style scripts in the future.
#
# **When to use it:**
#
# *   For learning Java basics.
# *   For quick scripts or prototypes.
# *   When participating in coding challenges or competitive programming where brevity is desired.
#
# **When to stick to the traditional way:**
#
# *   For any production code.
# *   For larger projects where explicit class structure is beneficial for organization and maintainability.
# *   When compatibility with older Java versions is required.
#
# ---
#
# Choose the method that best suits your needs! For general Java programming, the traditional way remains the standard. For experimentation or very simple scripts with a modern JDK, the minimal preview syntax is a neat option.
# Here's a business idea based on the provided "Hello, World!" context in Java 25, focusing on the friction points and opportunities highlighted by the introduction of new preview features:
#
# ---
#
# ## Business Idea: **"Modern Java Sandbox"** (or "Java 25 Playpen")
#
# **Core Problem Solved:**
# The introduction of new Java features, especially those in preview like "Unnamed Classes and Instance Main Methods," brings exciting possibilities but also adds friction for developers wanting to experiment. Setting up specific JDK versions, remembering command-line flags (`--enable-preview --source 25`), and managing project boilerplate for simple tests can be a barrier for beginners, experimenters, and competitive programmers.
#
# **The "Modern Java Sandbox" aims to remove this friction.**
#
# **Business Concept:**
# An online, cloud-based interactive development environment (IDE) and code playground specifically designed for rapidly experimenting with and learning **modern Java features**, including upcoming and preview functionalities from Java 21, 25, and beyond. It provides an intuitive interface to write, compile, and run Java code instantly, abstracting away the setup complexity.
#
# **Target Audience:**
#
# 1.  **Beginners:** Those just starting with Java can use the "minimal" `void main()` syntax without worrying about `public static void main(String[] args)` or class declarations, making their first "Hello, World!" experience extremely straightforward.
# 2.  **Experienced Developers:** Professionals looking to quickly try out new language features (like unnamed classes, virtual threads, pattern matching, records, etc.) without local JDK installations or project setup.
# 3.  **Educators & Students:** Teachers can use it for live coding demonstrations, and students can practice without environmental setup issues.
# 4.  **Competitive Programmers:** A fast, no-setup environment for quick problem-solving and algorithm testing.
# 5.  **Technical Interviewers/Interviewees:** For live coding assessments, allowing focus on logic rather than setup.
#
# **Key Features (Leveraging the "Hello, World!" example):**
#
# 1.  **Multi-Version Java Support:** Allow users to easily select and switch between various Java versions (e.g., Java 8, 11, 17, 21, 25, and the very latest preview builds).
# 2.  **Automated Preview Feature Toggling:** A simple checkbox or dropdown to "Enable Preview Features" for the selected Java version. This automatically applies the necessary `javac --enable-preview --source <version>` and `java --enable-preview` flags behind the scenes, exactly as described in the prompt.
# 3.  **Boilerplate-Reduced Templates:**
#     *   **"Hello, World!" Templates:** Provide one-click templates for both the "Traditional" (`public class HelloWorld {...}`) and "Minimal" (`void main() {...}`) "Hello, World!" examples, clearly showcasing the difference.
#     *   **New Feature Templates:** Pre-configured snippets to demonstrate other modern Java features (e.g., Records, Sealed Classes, Pattern Matching, Virtual Threads) that require specific Java versions or preview flags.
# 4.  **Instant Compilation & Execution:** Fast, cloud-based compilation and execution of Java code with real-time output display in the browser.
# 5.  **Code Sharing & Embedding:** Users can save their code, generate unique shareable URLs, and easily embed their code snippets (with live execution capabilities) onto blogs, tutorials, or documentation.
# 6.  **Basic IDE Functionality:** Syntax highlighting, basic auto-completion (for common library calls like `System.out.println`), and clear error messages.
# 7.  **Dependency Management (Advanced Tier):** For more complex examples, allow users to include common Maven/Gradle dependencies to test features with popular libraries (e.g., JUnit, Spring Boot snippets).
# 8.  **Interactive Tutorials & Challenges:** Guided paths demonstrating how to use new Java features effectively, starting with the very basics like the minimal `void main()`.
#
# **Monetization Model:**
#
# *   **Freemium:** Basic usage (limited execution time/storage, public code only, standard features) is free to attract a large user base.
# *   **Subscription Tiers (e.g., "Pro", "Team", "Enterprise"):**
#     *   **Pro Tier:** Unlimited execution, private code storage, faster/more powerful compute resources, advanced IDE features, custom JDK configurations.
#     *   **Team/Edu Tier:** Collaboration features, organization accounts, dedicated resources for educational institutions or corporate training.
# *   **API Access:** Offer an API for other platforms (LMS, blogs, documentation sites) to embed and run Java code snippets seamlessly within their own content.
# *   **Sponsorships/Ads:** Potentially non-intrusive ads on the free tier, or sponsored content/integration from Java tool vendors.
#
# **Why this idea leverages the prompt:**
#
# *   **Directly addresses the "How to Compile and Run" friction:** The detailed instructions with `--enable-preview` are complex for beginners; this platform automates it.
# *   **Highlights the "Why this feature?" of Unnamed Classes:** It makes Java more accessible for beginners and simplifies scripting, which this platform embraces.
# *   **Showcases the "When to use it" vs. "When to stick to traditional":** The platform would visually demonstrate both, helping users understand the trade-offs.
# *   **Future-Proofing:** Positioned as a platform for Java 25 and *upcoming* features, it caters to developers who want to stay at the cutting edge.
# *   **Educational Value:** Perfect for teaching and learning, from the very first "Hello, World!" to complex new language constructs.
#
# ---
